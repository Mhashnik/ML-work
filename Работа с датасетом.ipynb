# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
hr_data = pd.read_csv('C:\Pytorch\HR-Employee-Attrition.csv')
hr_data.head(7)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# ...

# %%
def plot_cat(col):
    plt.figure(figsize=(10,5))
    sns.countplot(x=col, hue='Attrition', data=hr_data)
    plt.show()
    
plot_cat('Age')

# %%
sns.catplot(x = 'Attrition', kind='count', data=hr_data, order=['No', 'Yes'])

# %%
hr_data['Attrition'].value_counts(normalize=True)
# Out:
# No     0.838776
# Yes    0.161224
# Name: Attrition, dtype: float64

# %%
hr_data.info()
print(hr_data.Age.dtype)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
hr_data.Age.dtype
#'Количество объектов': []
data_dict = {'№': [], 'Название признака': [], 'Тип данных': []}
n = 1
for index in list(hr_data.columns):
    data_dict['Название признака'].append(index)
    data_dict['№'].append(n)
    n += 1
    #data_dict['Количество объектов'].append(hr_data[index].size)
    if hr_data[index].dtype == 'int64':
        data_dict['Тип данных'].append('Числовой')
    else:
        data_dict['Тип данных'].append('Категориальный')
data_info = pd.DataFrame(data_dict)
data_info.head()
# Out:
#    № Название признака      Тип данных
# 0  1               Age        Числовой
# 1  2         Attrition  Категориальный
# 2  3    BusinessTravel  Категориальный
# 3  4         DailyRate        Числовой
# 4  5        Department  Категориальный

# %%
hr_data.hist(figsize=(20, 20))
# Out:
# array([[<AxesSubplot: title={'center': 'Age'}>,
#         <AxesSubplot: title={'center': 'DailyRate'}>,
#         <AxesSubplot: title={'center': 'DistanceFromHome'}>,
#         <AxesSubplot: title={'center': 'Education'}>,
#         <AxesSubplot: title={'center': 'EmployeeCount'}>],
#        [<AxesSubplot: title={'center': 'EmployeeNumber'}>,
#         <AxesSubplot: title={'center': 'EnvironmentSatisfaction'}>,
#         <AxesSubplot: title={'center': 'HourlyRate'}>,
#         <AxesSubplot: title={'center': 'JobInvolvement'}>,
#         <AxesSubplot: title={'center': 'JobLevel'}>],
#        [<AxesSubplot: title={'center': 'JobSatisfaction'}>,
#         <AxesSubplot: title={'center': 'MonthlyIncome'}>,
#         <AxesSubplot: title={'center': 'MonthlyRate'}>,
#         <AxesSubplot: title={'center': 'NumCompaniesWorked'}>,
#         <AxesSubplot: title={'center': 'PercentSalaryHike'}>],
#        [<AxesSubplot: title={'center': 'PerformanceRating'}>,
# ...

# %%
coll = ['Age', 'DailyRate', 'DistanceFromHome', 'EmployeeNumber', 'HourlyRate', 'JobRole', 'MonthlyIncome',
       'MonthlyRate', 'PercentSalaryHike']
hr_data[coll].describe()
# Out:
#                Age    DailyRate  DistanceFromHome  EmployeeNumber  \
# count  1470.000000  1470.000000       1470.000000     1470.000000
# mean     36.923810   802.485714          9.192517     1024.865306
# std       9.135373   403.509100          8.106864      602.024335
# min      18.000000   102.000000          1.000000        1.000000
# 25%      30.000000   465.000000          2.000000      491.250000
# 50%      36.000000   802.000000          7.000000     1020.500000
# 75%      43.000000  1157.000000         14.000000     1555.750000
# max      60.000000  1499.000000         29.000000     2068.000000
#
#         HourlyRate  MonthlyIncome   MonthlyRate  PercentSalaryHike
# count  1470.000000    1470.000000   1470.000000        1470.000000
# mean     65.891156    6502.931293  14313.103401          15.209524
# std      20.329428    4707.956783   7117.786044           3.659938
# min      30.000000    1009.000000   2094.000000          11.000000
# ...

# %%
hr_data['Attrition'].value_counts(normalize=True)
# Out:
# No     0.838776
# Yes    0.161224
# Name: Attrition, dtype: float64

# %%
sns.histplot(x = 'Age', hue='Attrition', data=hr_data)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Count'>

# %%
sns.catplot(x = 'Attrition', kind='count', data=hr_data, order=['No', 'Yes'])

# %%
sns.catplot(x = 'Attrition', kind='count', col='Gender', data=hr_data)

# %%
fig = plt.figure(figsize=[12, 8])
fig.subplots_adjust(hspace=0.3, wspace=0.3)
ax = fig.add_subplot(1, 3, 1)
sns.countplot(x = 'Over18', data=hr_data, ax=ax)
ax = fig.add_subplot(1, 3, 2)
sns.countplot(x = 'EmployeeCount', data=hr_data, color='darkgreen', ax=ax)
ax = fig.add_subplot(1, 3, 3)
sns.countplot(x = 'StandardHours', data=hr_data, color='darkred', ax=ax)
plt.show()
print(sns.catplot(x = 'Over18', kind='count', data=hr_data, height=4, aspect=0.7))
print(sns.catplot(x = 'EmployeeCount', kind='count', data=hr_data, height=4, aspect=0.7, color='darkgreen'))
print(sns.catplot(x = 'StandardHours', kind='count', data=hr_data, height=4, aspect=0.7, color='darkred'))

# %%
hr_data['Attrition'].replace({'Yes': 1, 'No': 0}, inplace=True)
coll_int = []
for name in list(hr_data.columns):
    if hr_data[name].dtype == 'int64':
        coll_int.append(name)
print(coll_int)
# Out:
# ['Age', 'Attrition', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
h = ['Attrition', 'Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
hr_data[h].corr()['Attrition']
# Out:
# Attrition                   1.000000
# Age                        -0.159205
# DailyRate                  -0.056652
# DistanceFromHome            0.077924
# Education                  -0.031373
# EmployeeNumber             -0.010577
# EnvironmentSatisfaction    -0.103369
# HourlyRate                 -0.006846
# JobInvolvement             -0.130016
# JobLevel                   -0.169105
# JobSatisfaction            -0.103481
# MonthlyIncome              -0.159840
# MonthlyRate                 0.015170
# NumCompaniesWorked          0.043494
# PercentSalaryHike          -0.013478
# PerformanceRating           0.002889
# RelationshipSatisfaction   -0.045872
# StockOptionLevel           -0.137145
# TotalWorkingYears          -0.171063
# TrainingTimesLastYear      -0.059478
# WorkLifeBalance            -0.063939
# YearsAtCompany             -0.134392
# YearsInCurrentRole         -0.160545
# YearsSinceLastPromotion    -0.033019
# YearsWithCurrManager       -0.156199
# ...

# %%
int_data = ['Attrition', 'Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
colormap = plt.cm.viridis
plt.figure(figsize=(20,20))
plt.title("Попарная корреляция признаков", y=1.05, size=25)

sns.heatmap(hr_data[int_data].corr(), square=True, annot=True, cmap=colormap)
# Out:
# <AxesSubplot: title={'center': 'Попарная корреляция признаков'}>

# %%
def plot_cat(col):
    plt.figure(figsize=(10,5))
    sns.countplot(x=col, hue='Attrition', data=hr_data)
    plt.show()
    
plot_cat('Age')

# %%
hr_data[['Attrition', 'Gender', 'OverTime']]
# Out:
#       Attrition  Gender OverTime
# 0             1  Female      Yes
# 1             0    Male       No
# 2             1    Male      Yes
# 3             0  Female      Yes
# 4             0    Male       No
# ...         ...     ...      ...
# 1465          0    Male       No
# 1466          0    Male       No
# 1467          0    Male      Yes
# 1468          0    Male       No
# 1469          0    Male       No
#
# [1470 rows x 3 columns]

# %%
hr_data.drop(['EmployeeCount', 'Over18', 'StandardHours'], axis=1, inplace=True)
hr_data['Attrition'].replace({'Yes': 1, 'No': 0}, inplace=True)
hr_data['Gender'].replace({'Male': 1, 'Female': 0}, inplace=True)
hr_data['OverTime'].replace({'Yes': 1, 'No': 0}, inplace=True)
hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   int64
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
hr_data[['BusinessTravel', 'MaritalStatus']]
# Out:
#          BusinessTravel MaritalStatus
# 0         Travel_Rarely        Single
# 1     Travel_Frequently       Married
# 2         Travel_Rarely        Single
# 3     Travel_Frequently       Married
# 4         Travel_Rarely       Married
# ...                 ...           ...
# 1465  Travel_Frequently       Married
# 1466      Travel_Rarely       Married
# 1467      Travel_Rarely       Married
# 1468  Travel_Frequently       Married
# 1469      Travel_Rarely       Married
#
# [1470 rows x 2 columns]

# %%
hr_data[['MaritalStatus', 'OverTime']][5:].head()
# Out:
#   MaritalStatus  OverTime
# 5        Single         0
# 6       Married         1
# 7      Divorced         0
# 8        Single         0
# 9       Married         0

# %%
d = pd.get_dummies(hr_data[['MaritalStatus']])
d[:][5:].head()
# Out:
#    MaritalStatus_Divorced  MaritalStatus_Married  MaritalStatus_Single
# 5                       0                      0                     1
# 6                       0                      1                     0
# 7                       1                      0                     0
# 8                       0                      0                     1
# 9                       0                      1                     0
